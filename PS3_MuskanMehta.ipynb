# %% [markdown]
# # PROBLEM SET 3
#
# # QUESTION 1
#
# Introduction:
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
# Occupations
#
# Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Step 2. Import the dataset from this address

# %%
data = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user",sep="|")

# %%
data
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# Step 3. Assign it to a variable called users

# %%
users = data

# %%
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# Step 4. Discover what is the mean age per occupation

# %%
users.groupby('occupation').age.mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
users['Male_Ratio_Per_Occupation'] = users.gender.apply(lambda x: True if x == 'M' else False)
users.Male_Ratio_Per_Occupation
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 938    False
# 939     True
# 940     True
# 941    False
# 942     True
# Name: Male_Ratio_Per_Occupation, Length: 943, dtype: bool

# %% [markdown]
# Sorting the values of Male ratio per occupation from most to least

# %%
(users.groupby('occupation').Male_Ratio_Per_Occupation.sum() / users.groupby('occupation').gender.count()).sort_values(ascending = False)
# Out:
# occupation
# doctor           1.000000
# engineer         0.970149
# technician       0.962963
# retired          0.928571
# programmer       0.909091
# executive        0.906250
# scientist        0.903226
# entertainment    0.888889
# lawyer           0.833333
# salesman         0.750000
# educator         0.726316
# student          0.693878
# other            0.657143
# marketing        0.615385
# writer           0.577778
# none             0.555556
# administrator    0.544304
# artist           0.535714
# librarian        0.431373
# healthcare       0.312500
# homemaker        0.142857
# dtype: float64

# %% [markdown]
# Step 6. For each occupation, calculate the minimum and maximum ages

# %%
users.groupby('occupation').age.agg(['min','max'])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %% [markdown]
# Step 7. For each combination of occupation and sex, calculate the mean age

# %%
users.groupby(['occupation', 'gender']).age.mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %% [markdown]
# Step 8. For each occupation present the percentage of women and men

# %%
countgender = users.groupby(['occupation', 'gender']).agg({'gender': 'count'})
countoccupation = users.groupby(['occupation']).count()
result = countgender.div(countoccupation, level = "occupation")*100
result.loc[:, 'gender']
# Out:
# occupation     gender
# administrator  F          45.569620
#                M          54.430380
# artist         F          46.428571
#                M          53.571429
# doctor         M         100.000000
# educator       F          27.368421
#                M          72.631579
# engineer       F           2.985075
#                M          97.014925
# entertainment  F          11.111111
#                M          88.888889
# executive      F           9.375000
#                M          90.625000
# healthcare     F          68.750000
#                M          31.250000
# homemaker      F          85.714286
#                M          14.285714
# lawyer         F          16.666667
#                M          83.333333
# librarian      F          56.862745
#                M          43.137255
# marketing      F          38.461538
#                M          61.538462
# none           F          44.444444
#                M          55.555556
# ...

# %% [markdown]
# # Question 2
#
# Euro Teams
#
# Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Step 2. Import the dataset from this address

# %%
Euroteams = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv")

# %%
Euroteams
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# Step 3. Assign it to a variable called euro12

# %%
euro12 = Euroteams
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# Step 4. Select only the Goal column

# %%
euro12['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# Step 5. How many teams participated in the Euro2012?

# %%
euro12['Team'].count()
# Out:
# 16

# %% [markdown]
# Step 6. What is the number of columns in the dataset?

# %%
c = len(euro12.columns)
print("The number of columns in the dataset are:",c)
# Out:
# The number of columns in the dataset are: 35

# %% [markdown]
# Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
discipline  = pd.DataFrame(euro12, columns = ['Team', 'Yellow Cards', 'Red Cards'])
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# Step 8. Sort the teams by Red Cards, then to Yellow Cards

# %%
discipline.sort_values(by=['Red Cards','Yellow Cards'])
# Out:
#                    Team  Yellow Cards  Red Cards
# 2               Denmark             4          0
# 5               Germany             4          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 4                France             6          0
# 12               Russia             6          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 0               Croatia             9          0
# 13                Spain            11          0
# 10             Portugal            12          0
# 7                 Italy            16          0
# 11  Republic of Ireland             6          1
# 9                Poland             7          1
# 6                Greece             9          1

# %% [markdown]
# Step 9. Calculate the mean Yellow Cards given per Team

# %%
(discipline.groupby('Team').agg(['mean']))['Yellow Cards']
# Out:
#                      mean
# Team
# Croatia               9.0
# Czech Republic        7.0
# Denmark               4.0
# England               5.0
# France                6.0
# Germany               4.0
# Greece                9.0
# Italy                16.0
# Netherlands           5.0
# Poland                7.0
# Portugal             12.0
# Republic of Ireland   6.0
# Russia                6.0
# Spain                11.0
# Sweden                7.0
# Ukraine               5.0

# %% [markdown]
# Step 10. Filter teams that scored more than 6 goals

# %%
euro12[euro12['Goals'] > 6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %% [markdown]
# Step 11.Select the teams that start with G

# %%
euro12[euro12['Team'].str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %% [markdown]
# Step 12. Select the first 7 columns

# %%
first7 = euro12[euro12.columns[range(7)]]
first7
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# Step 13. Select all columns except the last 3

# %%
euro12.iloc[:,:-3 ]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
accuracy = euro12[euro12['Team'].isin(['England', 'Italy', 'Russia'])]
accuracy[['Team','Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# # Question 3
#
# Housing
#
# Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd
import random

# %% [markdown]
# Step 2. Create 3 differents Series, each of length 100, as follows:
# • The first a random number from 1 to 4
# • The second a random number from 1 to 3
# • The third a random number from 10,000 to 30,000

# %%
series1 = [[random.randint(1,4)]for i in range(100)]
s1 = pd.DataFrame(series1)
series2 = [[random.randint(1,3)]for i in range(100)]
s2 = pd.DataFrame(series2)
series3 = [[random.randint(10000,30000)]for i in range(100)]
s3 = pd.DataFrame(series3)

# %%
s1
# Out:
#     0
# 0   1
# 1   3
# 2   2
# 3   2
# 4   4
# .. ..
# 95  2
# 96  4
# 97  3
# 98  4
# 99  4
#
# [100 rows x 1 columns]

# %%
s2
# Out:
#     0
# 0   2
# 1   3
# 2   3
# 3   3
# 4   2
# .. ..
# 95  2
# 96  3
# 97  2
# 98  1
# 99  3
#
# [100 rows x 1 columns]

# %%
s3
# Out:
#         0
# 0   26271
# 1   18154
# 2   20354
# 3   16896
# 4   13442
# ..    ...
# 95  21830
# 96  17820
# 97  16327
# 98  25108
# 99  17303
#
# [100 rows x 1 columns]

# %% [markdown]
# Step 3. Create a DataFrame by joining the Series by column

# %%
dfseries = pd.concat([s1,s2,s3],axis=1)
dfseries.columns=['1st Series','2nd Series','3rd Series']
dfseries
# Out:
#     1st Series  2nd Series  3rd Series
# 0            1           2       26271
# 1            3           3       18154
# 2            2           3       20354
# 3            2           3       16896
# 4            4           2       13442
# ..         ...         ...         ...
# 95           2           2       21830
# 96           4           3       17820
# 97           3           2       16327
# 98           4           1       25108
# 99           4           3       17303
#
# [100 rows x 3 columns]

# %% [markdown]
# Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter

# %%
dfseries.columns=['bedrs','bathrs','price_sqr_meter']
dfseries
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       1       2            26271
# 1       3       3            18154
# 2       2       3            20354
# 3       2       3            16896
# 4       4       2            13442
# ..    ...     ...              ...
# 95      2       2            21830
# 96      4       3            17820
# 97      3       2            16327
# 98      4       1            25108
# 99      4       3            17303
#
# [100 rows x 3 columns]

# %% [markdown]
# Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'

# %%
dfbigcolumn=pd.concat([s1,s2,s3])
dfbigcolumn.columns=['Bigcolumn']
dfbigcolumn
# Out:
#     Bigcolumn
# 0           1
# 1           3
# 2           2
# 3           2
# 4           4
# ..        ...
# 95      21830
# 96      17820
# 97      16327
# 98      25108
# 99      17303
#
# [300 rows x 1 columns]

# %% [markdown]
# Step 6. Ops it seems it is going only until index 99. Is it true?

# %% [markdown]
# Yes, as per the output result, the dataframe is displaying results till index 99 only.

# %% [markdown]
# Step 7. Reindex the DataFrame so it goes from 0 to 299

# %%
dfbigcolumn.reset_index()
# Out:
#      index  Bigcolumn
# 0        0          1
# 1        1          3
# 2        2          2
# 3        3          2
# 4        4          4
# ..     ...        ...
# 295     95      21830
# 296     96      17820
# 297     97      16327
# 298     98      25108
# 299     99      17303
#
# [300 rows x 2 columns]

# %% [markdown]
# # Question 4
#
# Wind Statistics
#
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise easier, in particular for the bonus question.
#
# You should be able to perform all of these operations without using a for loop or other looping construct.
#
# The data in 'wind.data' has the following format:
#
# Yr Mo Dy RPT VAL ROS KIL SHA BIR DUB CLA MUL CLO BEL MAL
# 61 1 1 15.04 14.96 13.17 9.29 NaN 9.87 13.67 10.25 10.83 12.58 18.50 15.04
# 61 1 2 14.71 NaN 10.83 6.50 12.62 7.67 11.50 10.04 9.79 9.67 17.54 13.83
# 61 1 3 18.50 16.88 12.33 10.13 11.17 6.17 11.25 NaN 8.50 7.67 12.75 12.71
#
# The first three columns are year, month, and day. The remaining 12 columns are average windspeeds in knots at 12 locations in Ireland on that day.

# %% [markdown]
# Step 1. Import the necessary libraries

# %%
import pandas as pd
import datetime

# %% [markdown]
# Step 2. Import the dataset from the attached file wind.txt

# %%
winddata = pd.read_csv('wind.txt',sep = '\s+')

# %%
winddata
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# ...

# %% [markdown]
# Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
winddata['Date']=pd.to_datetime(winddata[["Mo","Dy","Yr"]].astype(str).agg('-'.join, axis=1))
data = winddata.drop(columns=["Mo","Dy","Yr"])

# %%
data.head()
# Out:
#      RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL    CLO    BEL  \
# 0  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83  12.58  18.50
# 1  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79   9.67  17.54
# 2  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50   7.67  12.75
# 3  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83   5.88   5.46
# 4  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92  10.34  12.92
#
#      MAL       Date
# 0  15.04 2061-01-01
# 1  13.83 2061-01-02
# 2  12.71 2061-01-03
# 3  10.88 2061-01-04
# 4  11.83 2061-01-05

# %% [markdown]
# Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %%
import datetime as dt

def fix_year(x):
    if x.year > 2022:
        year = x.year - 100
    else:
        year = x.year
    return dt.date(year,x.month,x.day)

data['Date'] = data['Date'].apply(lambda x: fix_year(x))
data
# Out:
#         RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL    CLO  \
# 0     15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83  12.58
# 1     14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79   9.67
# 2     18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50   7.67
# 3     10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83   5.88
# 4     13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92  10.34
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04  14.00
# 6570  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25  18.05
# 6571  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50  16.42
# 6572  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46  12.12
# 6573  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58  11.38
#
#         BEL    MAL        Date
# 0     18.50  15.04  1961-01-01
# ...

# %% [markdown]
# Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data['Date'] = data['Date'].astype('datetime64[ns]')

data = data.set_index('Date')

# %% [markdown]
# Step 6. Compute how many values are missing for each location over the entire record.They should be ignored in all calculations below.

# %%
data.isnull().sum()
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %%
missingtotal = data.isnull().sum().sum()

# %%
missingtotal
# Out:
# 31

# %% [markdown]
# Step 7. Compute how many non-missing values there are in total.

# %%
data.notnull().sum()
# Out:
# RPT    6568
# VAL    6571
# ROS    6572
# KIL    6569
# SHA    6572
# BIR    6574
# DUB    6571
# CLA    6572
# MUL    6571
# CLO    6573
# BEL    6574
# MAL    6570
# dtype: int64

# %%
data.notnull().sum().sum()
# Out:
# 78857

# %% [markdown]
# Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
# A single number for the entire dataset.

# %%
data.mean().mean()
# Out:
# 10.227982360836924

# %% [markdown]
# Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days.
# A different set of numbers for each location.

# %%
loc_stats = data.agg(["count","min","max","mean","std"])
loc_stats
# Out:
#                RPT          VAL          ROS          KIL          SHA  \
# count  6568.000000  6571.000000  6572.000000  6569.000000  6572.000000
# min       0.670000     0.210000     1.500000     0.000000     0.130000
# max      35.800000    33.370000    33.840000    28.460000    37.540000
# mean     12.362987    10.644314    11.660526     6.306468    10.455834
# std       5.618413     5.267356     5.008450     3.605811     4.936125
#
#                BIR          DUB          CLA          MUL          CLO  \
# count  6574.000000  6571.000000  6572.000000  6571.000000  6573.000000
# min       0.000000     0.000000     0.000000     0.000000     0.040000
# max      26.160000    30.370000    31.080000    25.880000    28.210000
# mean      7.092254     9.797343     8.495053     8.493590     8.707332
# std       3.968683     4.977555     4.499449     4.166872     4.503954
#
#                BEL          MAL
# count  6574.000000  6570.000000
# min       0.130000     0.670000
# ...

# %% [markdown]
# Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.

# %%
day_stats = pd.DataFrame()
day_stats['min'] = data.min(axis=1)
day_stats['max'] = data.max(axis=1)
day_stats['mean'] = data.mean(axis=1)
day_stats['std'] = data.std(axis=1)

day_stats.head()
# Out:
#              min    max       mean       std
# Date
# 1961-01-01  9.29  18.50  13.018182  2.808875
# 1961-01-02  6.50  17.54  11.336364  3.188994
# 1961-01-03  6.17  18.50  11.641818  3.681912
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356

# %% [markdown]
# Step 11. Find the average windspeed in January for each location.
# Treat January 1961 and January 1962 both as January.

# %%
windjan = data[data.index.month == 1]
windjan.mean()
# Out:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %% [markdown]
# Step 12. Downsample the record to a yearly frequency for each location.

# %%
down_year = data.resample(rule = "Y")

down_year.mean()
# Out:
#                   RPT        VAL        ROS       KIL        SHA       BIR  \
# Date
# 1961-12-31  12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962-12-31  12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963-12-31  12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964-12-31  12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965-12-31  12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966-12-31  13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967-12-31  12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968-12-31  11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969-12-31  11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970-12-31  12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 1971-12-31  11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# ...

# %% [markdown]
# Step 13. Downsample the record to a monthly frequency for each location.

# %%
down_mon = data.resample(rule = "M")

down_mon.mean()
# Out:
#                   RPT        VAL        ROS       KIL        SHA        BIR  \
# Date
# 1961-01-31  14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-02-28  16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03-31  10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04-30  10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05-31   9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
# ...               ...        ...        ...       ...        ...        ...
# 1978-08-31   9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09-30  10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10-31   9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11-30  16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# 1978-12-31  16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
# ...

# %% [markdown]
# Step 14. Downsample the record to a weekly frequency for each location.

# %%
down_week = data.resample(rule = "W")

down_week.mean()
# Out:
#                   RPT        VAL        ROS        KIL        SHA        BIR  \
# Date
# 1961-01-01  15.040000  14.960000  13.170000   9.290000        NaN   9.870000
# 1961-01-08  13.541429  11.486667  10.487143   6.417143   9.474286   6.435714
# 1961-01-15  12.468571   8.967143  11.958571   4.630000   7.351429   5.072857
# 1961-01-22  13.204286   9.862857  12.982857   6.328571   8.966667   7.417143
# 1961-01-29  19.880000  16.141429  18.225714  12.720000  17.432857  14.828571
# ...               ...        ...        ...        ...        ...        ...
# 1978-12-03  14.934286  11.232857  13.941429   5.565714  10.215714   8.618571
# 1978-12-10  20.740000  19.190000  17.034286   9.777143  15.287143  12.774286
# 1978-12-17  16.758571  14.692857  14.987143   6.917143  11.397143   7.272857
# 1978-12-24  11.155714   8.008571  13.172857   4.004286   7.825714   6.290000
# 1978-12-31  14.951429  11.801429  16.035714   6.507143   9.660000   8.620000
#
# ...

# %% [markdown]
# Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
stats = data.resample(rule = "W").agg(['min','max','mean','std'])
stats.head()
# Out:
#               RPT                                VAL                    \
#               min    max       mean       std    min    max       mean
# Date
# 1961-01-01  15.04  15.04  15.040000       NaN  14.96  14.96  14.960000
# 1961-01-08  10.58  18.50  13.541429  2.631321   6.63  16.88  11.486667
# 1961-01-15   9.04  19.75  12.468571  3.555392   3.54  12.08   8.967143
# 1961-01-22   4.92  19.83  13.204286  5.337402   3.42  14.37   9.862857
# 1961-01-29  13.62  25.04  19.880000  4.619061   9.96  23.91  16.141429
#
#                         ROS         ...        CLO              BEL         \
#                  std    min    max  ...       mean       std    min    max
# Date                                ...
# 1961-01-01       NaN  13.17  13.17  ...  12.580000       NaN  18.50  18.50
# 1961-01-08  3.949525   7.62  12.33  ...   8.497143  1.704941   5.46  17.54
# 1961-01-15  3.148945   7.08  19.50  ...   7.571429  4.084293   5.25  20.71
# ...

# %% [markdown]
# # Question 5

# %% [markdown]
# Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Step 2. Import the dataset from this address.

# %%
dataset = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep = '\t')
dataset
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# Step 3. Assign it to a variable called chipo.

# %%
chipo = dataset
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# Step 5. What is the number of observations in the dataset?

# %%
len(chipo)
# Out:
# 4622

# %% [markdown]
# Step 6. What is the number of columns in the dataset?

# %%
len(chipo.columns)
# Out:
# 5

# %% [markdown]
# Step 7. Print the name of all the columns.

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# Step 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# Step 9. Which was the most-ordered item?

# %%
mostordereditem = chipo.groupby('item_name').sum().sort_values(['quantity'], ascending=False)
print("The most ordered item is:")
mostordereditem.head(1)
# Out:
# The most ordered item is:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %% [markdown]
# Step 10. For the most-ordered item, how many items were ordered?

# %%
mostordereditem.head(1).quantity
# Out:
# item_name
# Chicken Bowl    761
# Name: quantity, dtype: int64

# %% [markdown]
# Step 11. What was the most ordered item in the choice_description column?

# %%
chipo.groupby('choice_description').sum().sort_values(['quantity'], ascending = False).head(1)
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %% [markdown]
# Step 12. How many items were orderd in total?

# %%
chipo['quantity'].sum()
# Out:
# 4972

# %% [markdown]
# Step 13.
#
# • Turn the item price into a float
# • Check the item price type
# • Create a lambda function and change the type of item price
# • Check the item price type

# %%
chipo['item_price'].dtypes
# Out:
# dtype('O')

# %%
chipo['item_price'] = chipo['item_price'].str.replace('$','')
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x))
chipo['item_price'].dtypes
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25276\2863841606.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   chipo['item_price'] = chipo['item_price'].str.replace('$','')
# dtype('float64')

# %%
chipo['item_price'].astype(float)
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %% [markdown]
# Step 14. How much was the revenue for the period in the dataset?

# %%
chipo['quantity']=chipo['quantity'].astype(float)
chipo['Revenue']=chipo['item_price']*chipo['quantity']
chipo['Revenue'].sum()
# Out:
# 39237.02

# %% [markdown]
# Step 15. How many orders were made in the period?

# %%
chipo['order_id'].value_counts().count()
# Out:
# 1834

# %% [markdown]
# Step 16. What is the average revenue amount per order?

# %%
chipo['revenue'] = chipo['quantity'] * chipo['item_price']
ordernum = chipo.groupby(by = ['order_id']).sum()
ordernum.mean()['revenue']
# Out:
# 21.394231188658654

# %% [markdown]
# Step 17. How many different items are sold?

# %%
chipo['item_name'].value_counts().count()
# Out:
# 50

# %% [markdown]
# # Question 6
#
# Create a line plot showing the number of marriages and divorces per capita in the U.S. between 1867 and 2014. Label both lines and show the legend.
#
# Don't forget to label your axes!

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
us_mar_div_data = pd.read_csv("C:\\Users\\HP\\Downloads\\BDAT\\SEM 1\\Data Programming\\Assignment 3\\us-marriages-divorces-1867-2014.csv")
us_mar_div_data.sort_values('Year')
# Out:
#      Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0    1867   357000.0   10000.0    36970000                 9.7
# 1    1868   345000.0   10000.0    37885000                 9.1
# 2    1869   348000.0   11000.0    38870000                 9.0
# 3    1870   352000.0   11000.0    39905000                 8.8
# 4    1871   359000.0   12000.0    41010000                 8.8
# ..    ...        ...       ...         ...                 ...
# 140  2007  2197000.0  856000.0   301696000                 7.3
# 141  2008  2157000.0  844000.0   304543000                 7.1
# 142  2009  2080000.0  840000.0   307240000                 6.8
# 143  2010  2096000.0  872000.0   309776000                 6.8
# 144  2011  2118000.0  877000.0   312034000                 6.8
#
#      Divorces_per_1000
# 0                  0.3
# 1                  0.3
# 2                  0.3
# 3                  0.3
# 4                  0.3
# ..                 ...
# 140                2.8
# ...

# %%
data = us_mar_div_data
data.plot(x = 'Year', y = ['Marriages_per_1000', 'Divorces_per_1000'])
plt.title('Marriages and Divorces per capita in the U.S. between 1867 and 2014')
plt.ylabel('No. of Marriages and Divorces per Capita')
plt.xlabel('Year')
plt.grid(axis='x')
plt.show()

# %% [markdown]
# # Question 7
#
# Create a vertical bar chart comparing the number of marriages and divorces per capita in the U.S. between 1900, 1950, and 2000.
# Don't forget to label your axes!

# %%
us_mar_div_data = pd.read_csv("C:\\Users\\HP\\Downloads\\BDAT\\SEM 1\\Data Programming\\Assignment 3\\us-marriages-divorces-1867-2014.csv")
chartdata = data.loc[data.Year.isin([1900,1950,2000]),['Year','Marriages_per_1000','Divorces_per_1000']]
chartdata
# Out:
#      Year  Marriages_per_1000  Divorces_per_1000
# 33   1900                 9.3                0.7
# 83   1950                11.0                2.5
# 133  2000                 8.2                3.3

# %%
chartdata[{'Marriages_per_1000','Divorces_per_1000'}].plot.bar()
plt.title("Marriages and Divorces per capita in US", color = 'Blue', fontsize = 18)
plt.xlabel('Year', color = 'Red', fontsize = 14)
plt.ylabel('No. of Marriages and Divorces per capita', color = 'Red', fontsize = 14)
positions = (0,1,2)
labels = ("1900", "1950", "2000")
plt.xticks(positions, labels, rotation = 0)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1732\3933799597.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   chartdata[{'Marriages_per_1000','Divorces_per_1000'}].plot.bar()
# ([<matplotlib.axis.XTick at 0x1dfe7ddaac0>,
# ...
#  [Text(0, 0, '1900'), Text(1, 0, '1950'), Text(2, 0, '2000')])

# %% [markdown]
# # Question 8
#
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort the actors by their kill count and label each bar with the corresponding actor's name. Don't forget to label your axes!

# %%
actorkilldata = pd.read_csv("C:\\Users\\HP\\Downloads\\BDAT\\SEM 1\\Data Programming\\Assignment 3\\actor_kill_counts.csv")

# %%
actorkilldata
# Out:
#                    Actor  Count
# 0  Arnold Schwarzenegger    369
# 1           Chow Yun-Fat    295
# 2         Clint Eastwood    207
# 3             Clive Owen    194
# 4         Dolph Lundgren    239
# 5                 Jet Li    201
# 6           Nicolas Cage    204
# 7     Sylvester Stallone    267
# 8    Tomisaburo Wakayama    226
# 9          Wesley Snipes    193

# %%
chartdata = actorkilldata.sort_values('Count', ascending = True)

# %%
chartdata.plot.barh(x = 'Actor', y ='Count',legend = False,figsize = (12,10),color = 'Orange')
plt.title('Deadliest Actors in Hollywood', fontsize = 18,color = 'Blue')
plt.xlabel('Count of kills', fontsize = 14, color = 'Red')
plt.ylabel('Actor Name', fontsize = 14, color = 'Red')
# Out:
# Text(0, 0.5, 'Actor Name')

# %% [markdown]
# # Question 9
#
# Create a pie chart showing the fraction of all Roman Emperors that were assassinated.
#
# Make sure that the pie chart is an even circle, labels the categories, and shows the percentage breakdown of the categories.

# %%
assassindata =  pd.read_csv("C:\\Users\\HP\\Downloads\\BDAT\\SEM 1\\Data Programming\\Assignment 3\\roman-emperor-reigns.csv")

# %%
assassindata
# Out:
#            Emperor  Length_of_Reign         Cause_of_Death
# 0         Augustus            40.58  Possibly assassinated
# 1         Tiberius            22.50  Possibly assassinated
# 2         Caligula             4.83           Assassinated
# 3         Claudius            13.75  Possibly assassinated
# 4             Nero            13.67                Suicide
# ..             ...              ...                    ...
# 63   Valentinian I            11.00         Natural causes
# 64          Valens            14.00       Killed in battle
# 65         Gratian            16.00           Assassinated
# 66  Valentinian II            17.00  Possibly assassinated
# 67    Theodosius I            16.00         Natural causes
#
# [68 rows x 3 columns]

# %%
chartdata = assassindata.groupby("Cause_of_Death")['Emperor'].count()
chartdata.plot.pie(autopct="%.1f%%", figsize = (10,10) , fontsize = 14, ylabel = '', explode = [0.01]*8)
plt.title("Cause of Death of Roman Emperors", fontsize = 18, color = 'Blue')
# Out:
# Text(0.5, 1.0, 'Cause of Death of Roman Emperors')

# %% [markdown]
# # Question 10
#
# Create a scatter plot showing the relationship between the total revenue earned by arcades and the number of Computer Science PhDs awarded in the U.S. between 2000 and 2009.
#
# Don't forget to label your axes!
#
# Color each dot according to its year.

# %%
import pandas as pd
import seaborn as sns

# %%
revenuedata =  pd.read_csv("C:\\Users\\HP\\Downloads\\BDAT\\SEM 1\\Data Programming\\Assignment 3\\arcade-revenue-vs-cs-doctorates.csv")

# %%
revenuedata
# Out:
#    Year  Total Arcade Revenue (billions)  \
# 0  2000                            1.196
# 1  2001                            1.176
# 2  2002                            1.269
# 3  2003                            1.240
# 4  2004                            1.307
# 5  2005                            1.435
# 6  2006                            1.601
# 7  2007                            1.654
# 8  2008                            1.803
# 9  2009                            1.734
#
#    Computer Science Doctorates Awarded (US)
# 0                                       861
# 1                                       830
# 2                                       809
# 3                                       867
# 4                                       948
# 5                                      1129
# 6                                      1453
# 7                                      1656
# 8                                      1787
# 9                                      1611

# %%
sns.scatterplot(x='Total Arcade Revenue (billions)', y='Computer Science Doctorates Awarded (US)', hue='Year', data=revenuedata)
# Out:
# <AxesSubplot:xlabel='Total Arcade Revenue (billions)', ylabel='Computer Science Doctorates Awarded (US)'>
